# %% [markdown]
# <a href="https://colab.research.google.com/github/manvir720s/faceRecognition/blob/main/Face_recognition_with_face_recognition_library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.2MB 42kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566172 sha256=780e9943c407bb6b444df8c4058aa595d594cad4da66a012e8c5aece9fa3070b
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1a6131fc-0828-4008-a75f-a0d989591ace" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a6131fc-0828-4008-a75f-a0d989591ace">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving unn.jpg to unn.jpg

# %%
# !mkdir known

# %%
# !mkdir unknown

# %%
import face_recognition
import cv2
import os
from google.colab.patches import cv2_imshow
from skimage.transform import resize

# %%
#def read_img(path): 
 #   print (path)
  #  img=cv2.imread(path) 
   # print(img)
    #(h, w) = img.shape [:2]
    #width = 500
    #ratio = width / float (w)
    #height = int(h*ratio)
    #return cv2.resize (img, (width, height))

known_encodings = []
known_names = []
known_dir = 'known'

for file in os.listdir(known_dir): 
  img = cv2.imread(known_dir + '//' +file, 1)
  #(h, w) = img.shape [:2]
    #width = 500
    #ratio = width / float (w)
    #height = int(h*ratio)
    #return cv2.resize (img, (width, height))
  img_enc = face_recognition.face_encodings(img)[0]
  known_encodings.append(img_enc)
  known_names.append(file.split('.')[0])


unknown_dir = 'unknown'

for file in os.listdir(unknown_dir): 
   print ("Processing", file)
   img = cv2.imread(unknown_dir + "//" + file, 1)
   img_enc = face_recognition.face_encodings(img)[0]
   
   results = face_recognition.compare_faces(known_encodings, img_enc)
   
   for i in range (len(results)):
      if results[i]:
         name = (known_names[i])
         (top, right, bottom, left) = face_recognition.face_locations(img)[0]
         cv2.rectangle(img, (left, top), (right, bottom), (0, 0, 255), 2) 
         cv2.putText(img, name, (left+2, bottom+20), cv2.FONT_HERSHEY_PLAIN, 12, (255,255, 255), 1)
         (h, w) = img.shape [:2]
         width = 600
         ratio = width / float (w)
         height = int(h*ratio)
         dim = (width, height)
         resized = cv2.resize (img, dim, interpolation = cv2.INTER_AREA)
         cv2_imshow(resized)
         cv2.waitKey(0)
         cv2.destroyAllWindows()

   print(results)
# Out:
# Processing unn.jpg
# <PIL.Image.Image image mode=RGB size=600x900 at 0x7F20EE577B70>
# [True]

# %% [markdown]
# (h, w) = img.shape [:2]
#          width = 500
#          ratio = width / float (w)
#          height = int(h*ratio)
#          dsize = (width, height)
#          output = cv2.resize(img, dsize, interpolation = cv2.INTER_AREA)
#          cv2.imwrite(img, output)

# %% [markdown]
# https://www.youtube.com/watch?v=987QtKPZ-P0
